# %%
import streamlit as st
from path import Path
from datetime import date
import pandas as pd

# %%
import yfinance as yf
from prophet import Prophet
from fbprophet.plot import plot_plotly
from plotly import graph_objs as go

START = "2016-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

st.title("Anthon Stock Predictor")
stocks = ("AMZN","GOOG", "NFLX")

# Set number of years to predict
n_years = 3
period = n_years * 365

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

##Set stock to analyze
selected_stock = "AMZN"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("AMAZON:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# 2021-12-28 14:58:37.586
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\kubip\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2021-12-28 14:58:38.054 Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-12-28 14:58:38.070 NumExpr defaulting to 8 threads.
# [*********************100%***********************]  1 of 1 completed
# 2021-12-28 14:58:39.476 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# AMAZON:

# %%
print('Daily plot:')
fig1 = m.plot(forecast, xlabel='Datestamp', ylabel='Prediction')
# Out:
# Daily plot:

# %%
##Set stock to analyze
selected_stock = "GOOG"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("GOOGLE:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2021-12-28 15:07:52.131 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# GOOGLE:

# %%
##Set stock to analyze
selected_stock = "PFE"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("PFE:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2021-12-18 22:02:37.243 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# PFE:

# %%
print('Daily plot:')
fig1 = m.plot(forecast, xlabel='Datestamp', ylabel='Prediction')
# Out:
# Daily plot:

# %%
##Set stock to analyze
selected_stock = "NFLX"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("NETFLIX:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2021-12-28 15:08:24.520 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# NETFLIX:

# %%
print('Daily plot:')
fig1 = m.plot(forecast, xlabel='Datestamp', ylabel='Prediction')
# Out:
# Daily plot:
